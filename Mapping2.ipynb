# %%
import pandas as pd
import plotly.express as px
import plotly as pt
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

#data = pd.read_csv("/home/frakesmart/Desktop/LIPO/july_13_hampton_arcovia_hampton.csv")
data = pd.read_csv("/home/frakesmart/Desktop/LIPO/speed.csv")
data2 = data.loc[:,['Date', 'Time', 'Latitude', 'Longitude', 'Speed', 'Altitude', 'ir', 'luminosity', 'pm1s', 'pm25s', 'pm10s', 'pm1e', 'pm25e', 'pm10e', 'a03um01Lair', 'a05um01Lair', 'a1um01Lair', 'a25um01Lair', 'a5um01Lair', 'a10um01Lair', 'Co2', 'Temp', 'Hum']]


#DATE = data.Date
#TIME = data.Time
#LAT = data.Latitude
#LON = data.Longitude
#ALT = data.Altitude
#SPD = data.Speed
#HUM = data.Hum
#TMP = data.Temp
#PM1s = data.pm1s
#PM25s = data.pm25s
#PM10s = data.pm10s
#PM1e = data.pm1e
#PM25e = data.pm25e
#PM10e = data.pm10e
#IR = data.ir
#LUM = data.Luminosity

fig = px.scatter_mapbox(data, lat="Latitude", lon="Longitude", color="luminosity",size="luminosity", hover_name="luminosity", hover_data=["luminosity"],
                         size_max=15, zoom=12, height=600)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16661/1249683106.py in <module>
#      27 #LUM = data.Luminosity
#      28
# ---> 29 fig = px.scatter_mapbox(data, lat="Latitude", lon="Longitude", color="luminosity",size="luminosity", hover_name="luminosity", hover_data=["luminosity"],
#      30                          size_max=15, zoom=12, height=600)
#      31 fig.update_layout(mapbox_style="open-street-map")
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, center, mapbox_style, title, template, width, height)
# ...

# %%
import pandas as pd
import plotly.express as px
import plotly as pt
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

#data = pd.read_csv("/home/frakesmart/Desktop/LIPO/july_13_hampton_arcovia_hampton.csv")
data = pd.read_csv("/home/frakesmart/Desktop/LIPO/speed.csv")
data2 = data.loc[:,['Date', 'Time', 'Latitude', 'Longitude', 'Speed', 'Altitude', 'ir', 'luminosity', 'pm1s', 'pm25s', 'pm10s', 'pm1e', 'pm25e', 'pm10e', 'a03um01Lair', 'a05um01Lair', 'a1um01Lair', 'a25um01Lair', 'a5um01Lair', 'a10um01Lair', 'Co2', 'Temp', 'Hum']]



fig = px.scatter_mapbox(data, lat="Latitude", lon="Longitude", color="Speed",size="Speed", hover_name="Speed", hover_data=["Speed"],
                         size_max=15, zoom=12, height=600)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16661/7364868.py in <module>
#      11
#      12
# ---> 13 fig = px.scatter_mapbox(data, lat="Latitude", lon="Longitude", color="Speed",size="Speed", hover_name="Speed", hover_data=["Speed"],
#      14                          size_max=15, zoom=12, height=600)
#      15 fig.update_layout(mapbox_style="open-street-map")
#
# ~/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, center, mapbox_style, title, template, width, height)
#    1124     symbol mark on a Mapbox map.
#    1125     """
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(15, 15))
fig.subplots_adjust(hspace=0)

ax1.set_ylabel("$LUX$", fontsize=24)
ax1.yaxis.set_minor_locator(mticker.AutoMinorLocator())
ax1.plot(TIME, LUX, label = 'LUX')
ax1.plot(TIME, FULL, label = 'FULL')
ax1.plot(TIME, VIS, label = 'VIS')
ax1.plot(TIME, IR, label = 'IR')
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12)
ax1.grid()

ax2.set_xlabel('$TIME$', fontsize=24)
ax2.xaxis.set_minor_locator(mticker.AutoMinorLocator())
#ax2.set_ylabel('$R_{\odot}$ / $AU$', fontsize=24)
ax2.yaxis.set_minor_locator(mticker.AutoMinorLocator())
ax2.plot(TIME, HUM, 'tab:blue', label = 'HUM')
ax2.plot(TIME, TMP, 'tab:orange', label = 'TMP')
ax2.plot(TIME, CO, 'tab:green', label = 'CO')
ax2.plot(TIME, ROH, 'tab:red', label = 'ROH')
ax2.plot(TIME, CO2, 'tab:purple', label = 'CO2')
ax2.plot(TIME, TOL, 'tab:brown', label = 'TOL')
ax2.plot(TIME, NH4, 'tab:pink', label = 'NH4')
ax2.plot(TIME, ACE, 'tab:gray', label = 'ACE')
ax2.plot(TIME, PM5, 'tab:olive', label = 'PM5')
ax2.legend(loc='center left', bbox_to_anchor=(1, 1), fontsize=12)
ax2.grid()

plt.savefig('/home/frakesmart/Desktop/LIPO/GRAPHS/Feb27_Hampton_Rotonda_Hampton.eps', bbox_inches='tight', pad_inches=0.01)
plt.savefig('/home/frakesmart/Desktop/LIPO/GRAPHS/Feb27_Hampton_Rotonda_Hampton.pdf', bbox_inches='tight', pad_inches=0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16661/3840775055.py in <module>
#       7 ax1.set_ylabel("$LUX$", fontsize=24)
#       8 ax1.yaxis.set_minor_locator(mticker.AutoMinorLocator())
# ----> 9 ax1.plot(TIME, LUX, label = 'LUX')
#      10 ax1.plot(TIME, FULL, label = 'FULL')
#      11 ax1.plot(TIME, VIS, label = 'VIS')
#
# NameError: name 'TIME' is not defined

# %%
pt.offline.plot(fig, filename='Feb27_Hampton_Rotonda_Hampton_LUX.html', auto_open=False)

# %%
import pandas as pd
import plotly.express as px
import plotly as pt
import csv

month = []
day = []
year = []
#Time = []
#Location = []
Data = []


DD = input("Please enter your preferred Day (DD)")
day.append(DD)
MM = input("Please enter your preferred Month (MM)")
month.append(MM)
YYYY = input("Please enter your preferred Year (YYYY)")
year.append(YYYY)
data = input("Please enter your preferred Data to view (PM10, RH, degC, degF, FullSpectrum, VisibleLight, IR, LUX, mmHG, alt, TVOC, eCO2, H2, H, LPG, CH4, CO, ROH, CO2, ToL, NH4, Ace)")
Data.append(data)

#MandPas = pd.read_csv("/home/frakesmart/Desktop/Mandaluyong-and-Pasig-Data.csv")
MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])

#for i in range(len(Data)):
#    if data == Data[i]:
        

#        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="City", hover_data=[data, "month", "day", "year"],
#                                 size_max=15, zoom=12, height=600)
#        fig.update_layout(mapbox_style="open-street-map")
#        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
#        fig.show()
        
        
fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color="PM10", size="PM10", hover_name="PM10", hover_data=["PM10"],
                                 size_max=15, zoom=12, height=600)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
print(type(df['Hire Date'][0]))

# %%
# %matplotlib widget
import ipywidgets as widgets
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly as pt
import csv
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

month = []
day = []
year = []
#Time = []
#Location = []
Data = []


DD = input("Please enter your preferred Day (DD)")
day.append(DD)
MM = input("Please enter your preferred Month (MM)")
month.append(MM)
YYYY = input("Please enter your preferred Year (YYYY)")
year.append(YYYY)
data = str(input("Please enter your preferred Data to view (PM10, RH, degC, degF, FullSpectrum, VisibleLight, IR, LUX, mmHG, alt, TVOC, eCO2, H2, H, LPG, CH4, CO, ROH, CO2, ToL, NH4, Ace)"))
Data.append(data)

MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])

        
#*************************************************************
#PM10
if data ==  "PM10":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color="PM10", size="PM10", hover_name="PM10", hover_data=["PM10"],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#RH
elif data ==  "RH":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color="RH", size="RH", hover_name="RH", hover_data=["RH"],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#degC
elif data ==  "degC":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color="degC", size="degC", hover_name="degC", hover_data=["degC"],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#degF
elif data ==  "degF":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="degF", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#FullSpectrum
elif data ==  "FullSpectrum":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="FullSpectrum", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#VisibleLight
elif data ==  "VisibleLight":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="VisibleLight", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#IR
elif data ==  "IR":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="IR", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#LUX
elif data ==  "LUX":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="LUX", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#mmHg
elif data ==  "mmHg":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="mmHg", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#alt
elif data ==  "alt":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="alt", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#TVOC
elif data ==  "TVOC":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="TVOC", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#eCO2
elif data ==  "eCO2":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="eCO2", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#H2
elif data ==  "H2":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="H2", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#H
elif data ==  "H":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="H", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#LPG
elif data ==  "LPG":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="LPG", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#CH4
elif data ==  "CH4":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CH4", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#CO
elif data ==  "CO":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CO", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#ROH
elif data ==  "ROH":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="ROH", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#CO2
elif data ==  "CO2":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CO2", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#ToL
elif data ==  "ToL":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="ToL", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#NH4
elif data ==  "NH4":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="NH4", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#Ace
elif data ==  "Ace":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="Ace", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************

# %%
# %matplotlib widget
import ipywidgets as widgets
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly as pt
import csv
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

#month = 0
#day = 0
#year = 0



#DD = input("Please enter your preferred Day (DD)")
#day.append(DD)
#MM = input("Please enter your preferred Month (MM)")
#month.append(MM)
#YYYY = input("Please enter your preferred Year (YYYY)")
#year.append(YYYY)
data = str(input("Please enter your preferred Data to view (PM10, RH, degC, degF, FullSpectrum, VisibleLight, IR, LUX, mmHG, alt, TVOC, eCO2, H2, H, LPG, CH4, CO, ROH, CO2, ToL, NH4, Ace)"))



        
#*************************************************************
#PM10
if data ==  "PM10":

        
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)
        
    
        fig = px.scatter_mapbox(MandPasPM10, lat="lat", lon="lon", color="PM10", size="PM10", hover_name="PM10", hover_data=["PM10"],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#RH
elif data ==  "RH":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)


        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color="RH", size="RH", hover_name="RH", hover_data=["RH"],
                                size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#degC
elif data ==  "degC":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color="degC", size="degC", hover_name="degC", hover_data=["degC"],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#degF
elif data ==  "degF":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="degF", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#FullSpectrum
elif data ==  "FullSpectrum":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="FullSpectrum", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#VisibleLight
elif data ==  "VisibleLight":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="VisibleLight", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#IR
elif data ==  "IR":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="IR", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#LUX
elif data ==  "LUX":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="LUX", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#mmHg
elif data ==  "mmHg":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="mmHg", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#alt
elif data ==  "alt":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="alt", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#TVOC
elif data ==  "TVOC":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="TVOC", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#eCO2
elif data ==  "eCO2":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="eCO2", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#H2
elif data ==  "H2":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="H2", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#H
elif data ==  "H":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="H", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#LPG
elif data ==  "LPG":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="LPG", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#CH4
elif data ==  "CH4":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CH4", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#CO
elif data ==  "CO":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CO", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#ROH
elif data ==  "ROH":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="ROH", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#CO2
elif data ==  "CO2":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CO2", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#ToL
elif data ==  "ToL":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="ToL", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#NH4
elif data ==  "NH4":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="NH4", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************
#*************************************************************
#Ace
elif data ==  "Ace":
    
        beg = []
        en = []
        begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
        beg.append(begin)
        end = str(input("Please enter end date: (MM-DD-YYYY);"))
        en.append(end)

        
        MandPas = pd.read_csv("/home/frakesmart/Desktop/MandPas.csv", parse_dates=['Date'])
        MandPas['Date'] = pd.to_datetime(MandPas['Date'])
#        MandPas = pd.asfreq('D')
        mask = (MandPas['Date'] >= beg[0]) & (MandPas['Date'] <= en[0])
        MandPasPM10 = MandPas.loc[mask]
#        print(MandPasPM10)



        fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="Ace", hover_data=[data],
                                    size_max=15, zoom=12, height=600)
        fig.update_layout(mapbox_style="open-street-map")
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.show()
#*************************************************************

# %%
#*************************************************************
#degC
elif data ==  "degC":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color="degC", size="degC", hover_name="degC", hover_data=["degC"],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#degF
elif data ==  "degF":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="degF", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#FullSpectrum
elif data ==  "FullSpectrum":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="FullSpectrum", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#VisibleLight
elif data ==  "VisibleLight":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="VisibleLight", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#IR
elif data ==  "IR":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="IR", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#LUX
elif data ==  "LUX":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="LUX", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#mmHg
elif data ==  "mmHg":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="mmHg", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#alt
elif data ==  "alt":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="alt", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#TVOC
elif data ==  "TVOC":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="TVOC", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#eCO2
elif data ==  "eCO2":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="eCO2", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#H2
elif data ==  "H2":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="H2", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#H
elif data ==  "H":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="H", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#LPG
elif data ==  "LPG":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="LPG", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#CH4
elif data ==  "CH4":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CH4", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#CO
elif data ==  "CO":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CO", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#ROH
elif data ==  "ROH":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="ROH", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#CO2
elif data ==  "CO2":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="CO2", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#ToL
elif data ==  "ToL":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="ToL", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#NH4
elif data ==  "NH4":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="NH4", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************
#*************************************************************
#Ace
elif data ==  "Ace":
    fig = px.scatter_mapbox(MandPas, lat="lat", lon="lon", color=data, size=data, hover_name="Ace", hover_data=[data],
                                size_max=15, zoom=12, height=600)
    fig.update_layout(mapbox_style="open-street-map")
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    fig.show()
#*************************************************************

# %%
import csv

with open('employee_file2.csv', mode='w') as csv_file:
    fieldnames = ['emp_name', 'dept', 'birth_month']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'emp_name': 'John Smith', 'dept': 'Accounting', 'birth_month': 'November'})
    writer.writerow({'emp_name': 'Erica Meyers', 'dept': 'IT', 'birth_month': 'March'})

# %%
import numpy as np
import pandas as pd
 
df = pd.DataFrame(np.random.random((60,3)))
df['date'] = pd.date_range('2013-1-1', periods=60, freq='M')
mask = (df['date'] >= '09-01-2015') & (df['date'] <= '11-30-2016')
print(df.loc[mask])

# %%
import numpy as np
import pandas as pd

beg = []
en = []

begin = str(input("Please enter starting date: (MM-DD-YYYY);"))
beg.append(begin)
end = str(input("Please enter end date: (MM-DD-YYYY);"))
en.append(end)



#begin = '09-01-2016'
#end = '11-30-2016'
 
df = pd.DataFrame(np.random.random((60,3)))
df['Date'] = pd.date_range('2013-1-1', periods=60, freq='M')
mask = (df['Date'] >= beg[0]) & (df['Date'] <= en[0])
print(df.loc[mask])

# %%
# %matplotlib widget
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np

# set up plot
fig, ax = plt.subplots(figsize=(6, 4))
ax.set_ylim([-4, 4])
ax.grid(True)
 
# generate x values
x = np.linspace(0, 2 * np.pi, 100)
 
def my_sine(x, w, amp, phi):
    """
    Return a sine for x with angular frequeny w and amplitude amp.
    """
    return amp*np.sin(w * (x-phi))
 
@widgets.interact(w=(0, 10, 1), amp=(0, 4, .1), phi=(0, 2*np.pi+0.01, 0.01))
def update(w = 1.0, amp=1, phi=0):
    """Remove old lines from plot and plot new one"""
    [l.remove() for l in ax.lines]
    ax.plot(x, my_sine(x, w, amp, phi), color='C0')

# %%
from datetime import datetime as dt
import dash
import dash_html_components as html
import dash_core_components as dcc
import re

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
app.layout = html.Div([
    dcc.DatePickerRange(
        id='my-date-picker-range',
        min_date_allowed=dt(1995, 8, 5),
        max_date_allowed=dt(2017, 9, 19),
        initial_visible_month=dt(2017, 8, 5),
        end_date=dt(2017, 8, 25).date()
    ),
    html.Div(id='output-container-date-picker-range')
])


@app.callback(
    dash.dependencies.Output('output-container-date-picker-range', 'children'),
    [dash.dependencies.Input('my-date-picker-range', 'start_date'),
     dash.dependencies.Input('my-date-picker-range', 'end_date')])
def update_output(start_date, end_date):
    string_prefix = 'You have selected: '
    if start_date is not None:
        start_date = dt.strptime(re.split('T| ', start_date)[0], '%Y-%m-%d')
        start_date_string = start_date.strftime('%B %d, %Y')
        string_prefix = string_prefix + 'Start Date: ' + start_date_string + ' | '
    if end_date is not None:
        end_date = dt.strptime(re.split('T| ', end_date)[0], '%Y-%m-%d')
        end_date_string = end_date.strftime('%B %d, %Y')
        string_prefix = string_prefix + 'End Date: ' + end_date_string
    if len(string_prefix) == len('You have selected: '):
        return 'Select a date to see it displayed here'
    else:
        return string_prefix


if __name__ == '__main__':
    app.run_server(debug=True)

# %%
from django import forms
from bootstrap_daterangepicker import widgets, fields


class DemoForm(forms.Form):
    # Date Picker Fields
    date_single_normal = fields.DateField()
    date_single_with_format = fields.DateField(
        input_formats=['%d/%m/%Y'],
        widget=widgets.DatePickerWidget(
            format='%d/%m/%Y'
        )
    )
    date_single_clearable = fields.DateField(required=False)

    # Date Range Fields
    date_range_normal = fields.DateRangeField()
    date_range_with_format = fields.DateRangeField(
        input_formats=['%d/%m/%Y'],
        widget=widgets.DateRangeWidget(
            format='%d/%m/%Y'
        )
    )
    date_range_clearable = fields.DateRangeField(required=False)

    # DateTime Range Fields
    datetime_range_normal = fields.DateTimeRangeField()
    datetime_range_with_format = fields.DateTimeRangeField(
        input_formats=['%d/%m/%Y (%I:%M:%S)'],
        widget=widgets.DateTimeRangeWidget(
            format='%d/%m/%Y (%I:%M:%S)'
        )
    )
    datetime_range_clearable = fields.DateTimeRangeField(required=False)

# %%
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import dash_table_experiments as dt
from datetime import datetime as dti
from datetime import date
import re
from datetime import datetime as dt

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']


app = dash.Dash(name, external_stylesheets=external_stylesheets)
app.config.supress_callback_exceptions = True

app.layout = html.Div([
html.H4(children='Meteo Station of the SFI'),
dcc.DatePickerRange(
id='date-picker-range',
min_date_allowed=dti(2017, 1, 1),
max_date_allowed=dti(2018, 12, 26),
initial_visible_month=dti(2017, 8, 5),
end_date=dti(2017, 8, 25)
),
html.Button(id='button', n_clicks=0, children='Show table'),
html.Div(id='output-display',children='TEXT'),
html.Div(dt.DataTable(id='datatable', rows=[{}], max_rows_in_viewport=15))
])
@app.callback(dash.dependencies.Output('output-display', 'children'),
[dash.dependencies.Input('date-picker-range', 'start_date'),
dash.dependencies.Input('date-picker-range', 'end_date')]
)
def update_output(start_date, end_date, min_date_allowed):
    if start_date is not None:
        diff = dti(end_date) - dti(start_date)
        n_days = diff.days
        return n_days
if name == 'main':
    app.run_server(debug=True)

# %%
from django import forms
from bootstrap_daterangepicker import widgets, fields


class DemoForm(forms.Form):
    # Date Picker Fields
    date_single_normal = fields.DateField()
    date_single_with_format = fields.DateField(
        input_formats=['%d/%m/%Y'],
        widget=widgets.DatePickerWidget(
            format='%d/%m/%Y'
        )
    )
    date_single_clearable = fields.DateField(required=False)

    # Date Range Fields
    date_range_normal = fields.DateRangeField()
    date_range_with_format = fields.DateRangeField(
        input_formats=['%d/%m/%Y'],
        widget=widgets.DateRangeWidget(
            format='%d/%m/%Y'
        )
    )
    date_range_clearable = fields.DateRangeField(required=False)

    # DateTime Range Fields
    datetime_range_normal = fields.DateTimeRangeField()
    datetime_range_with_format = fields.DateTimeRangeField(
        input_formats=['%d/%m/%Y (%I:%M:%S)'],
        widget=widgets.DateTimeRangeWidget(
            format='%d/%m/%Y (%I:%M:%S)'
        )
    )
    datetime_range_clearable = fields.DateTimeRangeField(required=False)

# %%
from tkcalendar import DateEntry
root = tk.Tk()
cal = DateEntry(root, width=12, year=2019, month=6, day=22, 
background='darkblue', foreground='white', borderwidth=2)
cal.pack(padx=10, pady=10)
root.mainloop()

# %%
from django import forms

class DateForm(forms.Form):
    date = forms.DateTimeField(
        input_formats=['%d/%m/%Y %H:%M'],
        widget=forms.DateTimeInput(attrs={
            'class': 'form-control datetimepicker-input',
            'data-target': '#datetimepicker1'
        })
    )

# %%
import tkinter

import tkcalendar
import tkSimpleDialog

class CalendarDialog(tkSimpleDialog.Dialog):
    """Dialog box that displays a calendar and returns the selected date"""
    def body(self, master):
        self.calendar = ttkcalendar.Calendar(master)
        self.calendar.pack()

    def apply(self):
        self.result = self.calendar.selection

# Demo code:
def main():
    root = Tkinter.Tk()
    root.wm_title("CalendarDialog Demo")

    def onclick():
        cd = CalendarDialog(root)
        print (cd.result)

    button = Tkinter.Button(root, text="Click me to see a calendar!", command=onclick)
    button.pack()
    root.update()

    root.mainloop()


if __name__ == "__main__":
    main()

# %%
try:
    import tkinter as tk
    from tkinter import ttk
except ImportError:
    import Tkinter as tk
    import ttk

from tkcalendar import Calendar, DateEntry

def example1():
    def print_sel():
        print(cal.selection_get())

    top = tk.Toplevel(root)

    cal = Calendar(top,
                   font="Arial 14", selectmode='day',
                   cursor="hand1", year=2018, month=2, day=5)
    cal.pack(fill="both", expand=True)
    ttk.Button(top, text="ok", command=print_sel).pack()

def example2():
    top = tk.Toplevel(root)

    ttk.Label(top, text='Choose date').pack(padx=10, pady=10)

    cal = DateEntry(top, width=12, background='darkblue',
                    foreground='white', borderwidth=2)
    cal.pack(padx=10, pady=10)

root = tk.Tk()
s = ttk.Style(root)
s.theme_use('clam')

ttk.Button(root, text='Calendar', command=example1).pack(padx=10, pady=10)
ttk.Button(root, text='DateEntry', command=example2).pack(padx=10, pady=10)

root.mainloop()

# %%
"""
Simple calendar using ttk Treeview together with calendar and datetime
classes.
"""
import calendar

try:
    import Tkinter
    import tkFont
except ImportError: # py3k
    import tkinter as Tkinter
    import tkinter.font as tkFont

from tkinter import ttk

def get_calendar(locale, fwday):
    # instantiate proper calendar class
    if locale is None:
        return calendar.TextCalendar(fwday)
    else:
        return calendar.LocaleTextCalendar(fwday, locale)

class Calendar(ttk.Frame):
    # XXX ToDo: cget and configure

    datetime = calendar.datetime.datetime
    timedelta = calendar.datetime.timedelta

    def __init__(self, master=None, **kw):
        """
        WIDGET-SPECIFIC OPTIONS

            locale, firstweekday, year, month, selectbackground,
            selectforeground
        """
        # remove custom options from kw before initializating ttk.Frame
        fwday = kw.pop('firstweekday', calendar.MONDAY)
        year = kw.pop('year', self.datetime.now().year)
        month = kw.pop('month', self.datetime.now().month)
        locale = kw.pop('locale', None)
        sel_bg = kw.pop('selectbackground', '#ecffc4')
        sel_fg = kw.pop('selectforeground', '#05640e')

        self._date = self.datetime(year, month, 1)
        self._selection = None # no date selected

        ttk.Frame.__init__(self, master, **kw)

        self._cal = get_calendar(locale, fwday)

        self.__setup_styles()       # creates custom styles
        self.__place_widgets()      # pack/grid used widgets
        self.__config_calendar()    # adjust calendar columns and setup tags
        # configure a canvas, and proper bindings, for selecting dates
        self.__setup_selection(sel_bg, sel_fg)

        # store items ids, used for insertion later
        self._items = [self._calendar.insert('', 'end', values='')
                            for _ in range(6)]
        # insert dates in the currently empty calendar
        self._build_calendar()

        # set the minimal size for the widget
        self._calendar.bind('<Map>', self.__minsize)

    def __setitem__(self, item, value):
        if item in ('year', 'month'):
            raise AttributeError("attribute '%s' is not writeable" % item)
        elif item == 'selectbackground':
            self._canvas['background'] = value
        elif item == 'selectforeground':
            self._canvas.itemconfigure(self._canvas.text, item=value)
        else:
            ttk.Frame.__setitem__(self, item, value)

    def __getitem__(self, item):
        if item in ('year', 'month'):
            return getattr(self._date, item)
        elif item == 'selectbackground':
            return self._canvas['background']
        elif item == 'selectforeground':
            return self._canvas.itemcget(self._canvas.text, 'fill')
        else:
            r = ttk.tclobjs_to_py({item: ttk.Frame.__getitem__(self, item)})
            return r[item]

    def __setup_styles(self):
        # custom ttk styles
        style = ttk.Style(self.master)
        arrow_layout = lambda dir: (
            [('Button.focus', {'children': [('Button.%sarrow' % dir, None)]})]
        )
        style.layout('L.TButton', arrow_layout('left'))
        style.layout('R.TButton', arrow_layout('right'))

    def __place_widgets(self):
        # header frame and its widgets
        hframe = ttk.Frame(self)
        lbtn = ttk.Button(hframe, style='L.TButton', command=self._prev_month)
        rbtn = ttk.Button(hframe, style='R.TButton', command=self._next_month)
        self._header = ttk.Label(hframe, width=15, anchor='center')
        # the calendar
        self._calendar = ttk.Treeview(show='', selectmode='none', height=7)

        # pack the widgets
        hframe.pack(in_=self, side='top', pady=4, anchor='center')
        lbtn.grid(in_=hframe)
        self._header.grid(in_=hframe, column=1, row=0, padx=12)
        rbtn.grid(in_=hframe, column=2, row=0)
        self._calendar.pack(in_=self, expand=1, fill='both', side='bottom')

    def __config_calendar(self):
        cols = self._cal.formatweekheader(3).split()
        self._calendar['columns'] = cols
        self._calendar.tag_configure('header', background='grey90')
        self._calendar.insert('', 'end', values=cols, tag='header')
        # adjust its columns width
        font = tkFont.Font()
        maxwidth = max(font.measure(col) for col in cols)
        for col in cols:
            self._calendar.column(col, width=maxwidth, minwidth=maxwidth,
                anchor='e')

    def __setup_selection(self, sel_bg, sel_fg):
        self._font = tkFont.Font()
        self._canvas = canvas = Tkinter.Canvas(self._calendar,
            background=sel_bg, borderwidth=0, highlightthickness=0)
        canvas.text = canvas.create_text(0, 0, fill=sel_fg, anchor='w')

        canvas.bind('<ButtonPress-1>', lambda evt: canvas.place_forget())
        self._calendar.bind('<Configure>', lambda evt: canvas.place_forget())
        self._calendar.bind('<ButtonPress-1>', self._pressed)

    def __minsize(self, evt):
        width, height = self._calendar.master.geometry().split('x')
        height = height[:height.index('+')]
        self._calendar.master.minsize(width, height)

    def _build_calendar(self):
        year, month = self._date.year, self._date.month

        # update header text (Month, YEAR)
        header = self._cal.formatmonthname(year, month, 0)
        self._header['text'] = header.title()

        # update calendar shown dates
        cal = self._cal.monthdayscalendar(year, month)
        for indx, item in enumerate(self._items):
            week = cal[indx] if indx < len(cal) else []
            fmt_week = [('%02d' % day) if day else '' for day in week]
            self._calendar.item(item, values=fmt_week)

    def _show_selection(self, text, bbox):
        """Configure canvas for a new selection."""
        x, y, width, height = bbox

        textw = self._font.measure(text)

        canvas = self._canvas
        canvas.configure(width=width, height=height)
        canvas.coords(canvas.text, width - textw, height / 2 - 1)
        canvas.itemconfigure(canvas.text, text=text)
        canvas.place(in_=self._calendar, x=x, y=y)

    # Callbacks

    def _pressed(self, evt):
        """Clicked somewhere in the calendar."""
        x, y, widget = evt.x, evt.y, evt.widget
        item = widget.identify_row(y)
        column = widget.identify_column(x)

        if not column or not item in self._items:
            # clicked in the weekdays row or just outside the columns
            return

        item_values = widget.item(item)['values']
        if not len(item_values): # row is empty for this month
            return

        text = item_values[int(column[1]) - 1]
        if not text: # date is empty
            return

        bbox = widget.bbox(item, column)
        if not bbox: # calendar not visible yet
            return

        # update and then show selection
        text = '%02d' % text
        self._selection = (text, item, column)
        self._show_selection(text, bbox)

    def _prev_month(self):
        """Updated calendar to show the previous month."""
        self._canvas.place_forget()

        self._date = self._date - self.timedelta(days=1)
        self._date = self.datetime(self._date.year, self._date.month, 1)
        self._build_calendar() # reconstuct calendar

    def _next_month(self):
        """Update calendar to show the next month."""
        self._canvas.place_forget()

        year, month = self._date.year, self._date.month
        self._date = self._date + self.timedelta(
            days=calendar.monthrange(year, month)[1] + 1)
        self._date = self.datetime(self._date.year, self._date.month, 1)
        self._build_calendar() # reconstruct calendar

    # Properties

    @property
    def selection(self):
        """Return a datetime representing the current selected date."""
        if not self._selection:
            return None

        year, month = self._date.year, self._date.month
        return self.datetime(year, month, int(self._selection[0]))

def test():
    import sys
    root = Tkinter.Tk()
    root.title('Ttk Calendar')
    ttkcal = Calendar(firstweekday=calendar.SUNDAY)
    ttkcal.pack(expand=1, fill='both')

    if 'win' not in sys.platform:
        style = ttk.Style()
        style.theme_use('clam')

    root.mainloop()

if __name__ == '__main__':
    test()

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv("/home/frakesmart/Desktop/LIPO/hampton_rotonda_hampton_feb_27.csv")
#data = pd.read_csv("/home/frakesmart/Desktop/LIPO/international-visitors-london-raw.csv")


ALL = 'ALL'

def unique_sorted_values_plus_ALL(array):
    unique = array.unique().tolist()
    unique.sort()
    unique.insert(0, ALL)
    return unique

# %%
dropdown_year = widgets.Dropdown(options = unique_sorted_values_plus_ALL(data.TIME))
dropdown_purpose = widgets.Dropdown(options = unique_sorted_values_plus_ALL(data.PM5))
output_year = widgets.Output()
plot_output = widgets.Output()

    
def common_filtering(TIME, PM5):
    output.clear_output()
    plot_output.clear_output()
    
    if (TIME == ALL) & (PM5 == ALL):
        common_filter = data
    elif (TIME == ALL):
        common_filter = data[data.PM5 == PM5]
    elif (PM5 == ALL):
        common_filter = data[data.TIME == TIME]
    else:
        common_filter = data[(data.TIME == TIME) & (data.PM5 == PM5)]
    with output:
        display(common_filter)
        
    with plot_output:
        sns.kdeplot()
        plt.show()
        
        
def dropdown_year_eventhandler(change):
    common_filtering(dropdown_purpose.value, change.new)

def dropdown_purpose_eventhandler(change):
    common_filtering(dropdown_year.value, change.new)
    
       
dropdown_year.observe(dropdown_year_eventhandler, names='value')
dropdown_purpose.observe(dropdown_purpose_eventhandler, names='value')

display(dropdown_year)
display(dropdown_purpose)
output = widgets.Output()
# Out:
# Dropdown(options=('ALL', '08:46:35', '08:46:38', '08:46:41', '08:46:44', '08:46:48', '08:46:51', '08:46:54', '…
# Dropdown(options=('ALL', -85.62, -84.78, -83.94, -83.1, -82.26, -81.42, -80.58, -79.74, -78.9, -78.06, -77.22,…

# %%
display(output)
#display(plot_output)
# Out:
# Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': '          DATE      TIME      LAT     …

# %%
import numpy as np
import pandas as pd
from ipywidgets.widgets import interact, SelectMultiple

import pandas as pd
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv("/home/frakesmart/Desktop/LIPO/hampton_rotonda_hampton_feb_27.csv")
data2 = data.loc[:,['HUM','TMP', 'CO', 'ROH','CO2', 'TOL', 'NH4', 'ACE', 'PM5', 'FULL', 'VIS', 'IR', 'LUX']]

opts = data2.columns.values
output = widgets.Output()
sel_mul = SelectMultiple(description="Variables",options=opts,disabled=False)
@interact(variables=sel_mul)
def plot_multiple(variables):
    output.clear_output()
    data[list(variables)].plot(figsize = (15,5))
# Out:
# interactive(children=(SelectMultiple(description='Variables', options=('HUM', 'TMP', 'CO', 'ROH', 'CO2', 'TOL'…
